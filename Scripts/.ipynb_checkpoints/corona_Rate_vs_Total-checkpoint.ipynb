# %%
'''Linregression model wrong!!!!!!!!!!'''

import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

total = [48,79,130,159,196,262,482,670,799,1040,1176,1457,1908,2078,3675,4585,5795,7272,9257,12327,15320,
              19848,22213,24873,29056,32986,37323,43938,50871,57695,62095,66885,71808,77872,84794,91159,96092,
              100123,103374,107663,113296,118181,122171,124908,127854,130072,131359,134753,137698,141397,143342,
              145184,147065,148291,150648,153129,154999]



growth=[total[i+1]-total[i] for i in range(len(total)-1)]

total = np.asarray(total)
growth = np.asarray(growth)
x = total
y = growth


gradient, intercept, r_value, p_value, std_err = linregress(np.log(x[:28]),(np.log(y[:28])))

fig, ax = plt.subplots(figsize=(10,5))
ax.set_yscale('log')
ax.set_xscale('log')
ax.set_ylim(10, 10000)
ax.set_xlim(10, 200000)
ax.set_xlabel('Total cases')
ax.set_ylabel('Growth')

ax.scatter(x[:len(x)-1], y, alpha=0.5, s=50)
ax.plot(x[:len(x)-1], y)
ax.plot((x[:28]),(y[:28]))

z = np.linspace(x[0], x[28], 100)
ax.plot((z), gradient*(z)+intercept,'m')

intercept
# Out:
# -0.1211708359221797

# %%
x = np.linspace(1,100,99)
y = np.linspace(1,100,99)

fig, ax = plt.subplots()
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim(1, 10)
ax.set_xlim(1, 10)

ax.scatter(np.log(x), np.log(y))

gradient, intercept, r_value, p_value, std_err = linregress(x,y)
ax.plot(x, gradient*x+intercept)

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

total = [48,79,130,159,196,262,482,670,799,1040,1176,1457,1908,2078,3675,4585,5795,7272,9257,12327,15320,
              19848,22213,24873,29056,32986,37323,43938,50871,57695,62095,66885,71808,77872,84794,91159,96092,
              100123,103374,107663,113296,118181,122171,124908,127854,130072,131359,134753,137698,141397,143342,
              145184,147065,148291,150648,153129,154999]



growth=[total[i+1]-total[i] for i in range(len(total)-1)]

total = np.asarray(total)
growth = np.asarray(growth)

x = np.log(total)
y = np.log(growth)


gradient, intercept, r_value, p_value, std_err = linregress(x[:28],y[:28])

fig, ax = plt.subplots(figsize=(10,5))

ax.set_xlabel('log(Total cases)')
ax.set_ylabel('log(Growth)')

ax.scatter(x[:len(x)-1], y, alpha=0.5, s=50)
ax.plot(x[:len(x)-1], y)
ax.plot((x[:28]),(y[:28]))

x = np.linspace(x[0], x[28], 2)
ax.plot((x), gradient*(x)+intercept,'m')

intercept
gradient
# Out:
# 0.8376754887754541
