# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
#help(np.random)x

T=100
xvalues=np.empty(T)

for t in range(T):
    x=np.random.pareto(1)
    xvalues[t]=x

#bins=[x+n for x in range(T)]
plt.plot(xvalues)
plt.show()
#bins()
plt.hist(xvalues, log=True)
plt.show()
